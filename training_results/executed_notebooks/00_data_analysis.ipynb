# %% [markdown]
# # 00 — Dataset analysis and experimental scope
#
# This notebook establishes the evidence base for the controlled experiments. It reports the number of query-level samples, source images, object classes, and part queries in each prepared Pascal-Part-116 split. No model is trained here.
#
# The separation between `train_seen`, `validation_seen`, `test_seen`, and `test_unseen` is retained throughout the study. Validation data controls early stopping and checkpoint selection. Test data is used only after selection.

# %%
from pathlib import Path
import os
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "final_training_notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / "final_training").is_dir():
    raise FileNotFoundError("Run this notebook from the repository or final_training_notebooks directory")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

RUN_ID = os.environ.get("FINAL_TRAINING_RUN_ID", "manual")
print("Project root:", PROJECT_ROOT)
print("Training run:", RUN_ID)
# Out:
# Project root: /anvme/workspace/v123be52-cv_project/Computer_Vision_Object-Relative-Spatial-Encoding-for-Open-Vocabulary-Part-Segmentation
# Training run: training_4217799

# %% [markdown]
# ## Analysis
#
# The saved table and figure make dataset scale and query imbalance explicit before model comparison. This notebook can be executed independently.

# %%
from final_training.training_core import run_data_analysis

overview = run_data_analysis()
overview
# Out:
#           split  queries  images  object_classes  part_queries
#      train_seen    32698    5204              11            41
# validation_seen     3708     580              11            41
#       test_seen     3371     597              11            41
#     test_unseen     1586     268               5            25
#              split  queries  images  object_classes  part_queries
# 0       train_seen    32698    5204              11            41
# 1  validation_seen     3708     580              11            41
# 2        test_seen     3371     597              11            41
# 3      test_unseen     1586     268               5            25

# %% [markdown]
# ## Interpretation
#
# All later experiments use the same prepared splits and seed. Consequently, architectural and regularization changes are compared under a controlled data protocol.

# %% [markdown]
# ## Saved graph
#
# ![Dataset overview](../data_analysis/dataset_overview.png)
